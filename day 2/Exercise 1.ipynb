# %%
maxdistance = int(1000)
temperature = float(20.2)
greet_ing = 'Ciao'
isRaining = False

# %%
"""1st_value -> first_value
Total$Amount -> total_amount
calcNum -> calc_num
Data-Entry -> data_entry"""
# Out:
# '1st_value -> first_value\nTotal$Amount -> total_amount\ncalcNum -> calc_num\nData-Entry -> data_entry'

# %%
number1 = int(42)

# %%
number1 = float(number1)
type(number)
# Out:
# float

# %%
number2 = float(3.14)

# %%
number2 = int(float(3.14))
type(number2)
# Out:
# int

# %%
number3 = float(99.99)

# %%
number3 = str(number3)
type(number3)
number3
# Out:
# '99.99'

# %%
number3 = float(number3)
type(number3)
# Out:
# float

# %%
single_quotes_string = 'this is a string made with single quotes'
double_quotes_string = "this is a string made with double quotes"
multiple_quotes_string = """this is a string made with multiple quotes"""
# Out:
# 'this is a string made with multiple quotes'

# %%
name = 'Davide'
print(f'Hello! My name is {name}')
# Out:
# Hello! My name is Davide

# %%
presentazione = 'Hello! My name is Davide'

# %%
presentazione[0:5]
# Out:
# 'Hello'

# %%
len(presentazione)
# Out:
# 24

# %%
pr = presentazione[0:2] + presentazione[22:24]
pr
# Out:
# 'Hede'

# %%
prr = presentazione[0:2].__add__(presentazione[22:24])
prr
# Out:
# 'Hede'

# %%
frase1 = 'hello'
frase1 = frase1[0:2].upper() + 'llo my name is Davi'
frase1
# Out:
# 'HEllo my name is Davi'

# %%
frase2 = 'de'.upper()
frase2
# Out:
# 'DE'

# %%
frase_completa = frase1.__add__(frase2)
frase_completa
# Out:
# 'HEllo my name is DaviDE'

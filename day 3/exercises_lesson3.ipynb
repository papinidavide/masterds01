# %%
def calculate_area(width, height):
    area = width * height
    return(area)

# %%
calculate_area(3,2)
# Out:
# 6

# %%
def introduce(name, age):
    print(f'Hello!, my name is {name} and I am {age}')

# %%
introduce('Davide', 24)
# Out:
# Hello!, my name is Davide and I am 24

# %%
def first_and_last(l):
    return l[0], l[-1]

# %%
l = [0,1,2,3,4,5,6]
first_and_last(l)
# Out:
# (0, 6)
